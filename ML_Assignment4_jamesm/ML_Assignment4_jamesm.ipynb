# %% [markdown]
# Problem #1

# %%
from tensorflow.keras import layers
from tensorflow.keras import backend as K
from tensorflow.keras import models
from tensorflow.keras import metrics
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#Using keras mnist data instead of given mnist_784.csv for past assignment for simplicity
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = (x_train/255).reshape(60000, 784)
x_test = (x_test/255).reshape(10000, 784)

#Input
inputImg = layers.Input(shape=(784,))

#Keeping lists of autoencoders with different compression rates
nodeCounts = [16, 8, 5, 2]
historys = []
for i in range(len(nodeCounts)):
    #Encoder
    x = layers.Dense(64, activation='relu')(inputImg)
    encoded = layers.Dense(nodeCounts[i], activation='relu')(x)
    
    #Decoder
    x = layers.Dense(64, activation='relu')(encoded)
    output = layers.Dense(784, activation='sigmoid')(x)

    #Compiling models
    encoder = models.Model(inputImg, encoded)
    autoencoder = models.Model(inputImg, output)
    autoencoder.compile(optimizer='rmsprop', loss='binary_crossentropy')
    #Decreasing batch size had a huge impact of performance but also slowed down training
    historys.append(autoencoder.fit(x_train, x_train, epochs=50, batch_size=256, shuffle=True,
                              validation_data=(x_test, x_test)))

#Plotting
plt.plot(historys[0].history['val_loss'])
plt.plot(historys[1].history['val_loss'])
plt.plot(historys[2].history['val_loss'])
plt.plot(historys[3].history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('Different Compression rate\'s (CR) loss')
plt.legend(['CR=49', 'CR=98', 'CR=156.8', 'CR=392'], loc='upper right')
plt.show()
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.2315 - val_loss: 0.1785
# Epoch 2/50
# 56064/60000 [===========================>..] - ETA: 0s - loss: 0.1667
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-9fd87ffda586> in <module>()
#      36     #Decreasing batch size had a huge impact of performance but also slowed down training
#      37     historys.append(autoencoder.fit(x_train, x_train, epochs=50, batch_size=256, shuffle=True,
# ---> 38                               validation_data=(x_test, x_test)))
#      39
#      40 #Plotting
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     725         max_queue_size=max_queue_size,
#     726         workers=workers,
# --> 727         use_multiprocessing=use_multiprocessing)
#     728
#     729   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     673         validation_steps=validation_steps,
#     674         validation_freq=validation_freq,
# --> 675         steps_name='steps_per_epoch')
#     676
#     677   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     392
#     393         # Get outputs.
# --> 394         batch_outs = f(ins_batch)
#     395         if not isinstance(batch_outs, list):
#     396           batch_outs = [batch_outs]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# From the results above one can clearly see that as the compression rate increase the reconstruction accuracy goes down (loss goes up).
# **
# When using 'accuracy' metrics into the 'compile()' step trhe training started giving me values of 500+ for loss and below 0.01 for accuracy so I left that out and hoped loss will suffice to represent the performance.
# **

# %%
#Plotting representation of 2 node bottleneck layer

#Grabbing only classes 0, 1, 2, and 3
x_test_new = []
y_test_new = []
for i in range(len(y_test)):
    if y_test[i]<4:
        x_test_new.append(x_test[i])
        y_test_new.append(y_test[i])

y_test_new = np.array(y_test_new)
x_test_new = np.array(x_test_new)

#Generating points
x_test_encoded = encoder.predict(x_test_new, batch_size=256)
plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c=y_test_new)
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ae548771aeff> in <module>()
#       1 x_test_new = []
#       2 y_test_new = []
# ----> 3 for i in range(len(y_test)):
#       4     if y_test[i]<4:
#       5         x_test_new.append(x_test[i])
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# Problem #2

# %%
#I used a starting point of (2, 0)
#I used a default reward of -1 for each state
#I assumed each reward/trap state was terminal
#For Q-Learning I used a learning rate of 0.8

#With Q-Learning I got:
# [[ 0.40354785  7.36098107  2.87530616  0.327641  ]
#  [ 8.03453404  0.21923744  1.97936918  6.16347295]
#  [ 2.70918676 -0.79486551 -0.48160546  1.95353194]
#  [ 0.25152245  1.02887878 -1.799135    0.28770349]]

#With value iteration I got:
# [[ 8.          6.75        5.35185185  6.        ]
#  [ 6.75        5.49166666  4.16666666  4.68518518]
#  [ 5.31960607  3.87645742  3.0603323   3.39353479]
#  [ 1.          2.33127999  1.30116875 -4.        ]]

# %% [markdown]
# Problem #3

# %%
#Just declaring that the below code wasn't written by me

import random
import gym
import numpy as np
from collections import deque
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

from scores.score_logger import ScoreLogger

ENV_NAME = "CartPole-v1"

GAMMA = 0.95
LEARNING_RATE = 0.001

MEMORY_SIZE = 1000000
BATCH_SIZE = 20

EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.01
EXPLORATION_DECAY = 0.995


class DQNSolver:

    def __init__(self, observation_space, action_space):
        self.exploration_rate = EXPLORATION_MAX

        self.action_space = action_space
        self.memory = deque(maxlen=MEMORY_SIZE)

        self.model = Sequential()
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))
        self.model.add(Dense(24, activation="relu"))
        self.model.add(Dense(self.action_space, activation="linear"))
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() < self.exploration_rate:
            return random.randrange(self.action_space)
        q_values = self.model.predict(state)
        return np.argmax(q_values[0])

    def experience_replay(self):
        if len(self.memory) < BATCH_SIZE:
            return
        batch = random.sample(self.memory, BATCH_SIZE)
        for state, action, reward, state_next, terminal in batch:
            q_update = reward
            if not terminal:
                #The line underneath this comment is where the temperal difference error is calculated
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
            q_values = self.model.predict(state)
            q_values[0][action] = q_update
            self.model.fit(state, q_values, verbose=0)
        self.exploration_rate *= EXPLORATION_DECAY
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)


def cartpole():
    env = gym.make(ENV_NAME)
    score_logger = ScoreLogger(ENV_NAME)
    observation_space = env.observation_space.shape[0]
    action_space = env.action_space.n
    dqn_solver = DQNSolver(observation_space, action_space)
    run = 0
    while True:
        run += 1
        state = env.reset()
        state = np.reshape(state, [1, observation_space])
        step = 0
        while True:
            step += 1
            #env.render()
            action = dqn_solver.act(state)
            state_next, reward, terminal, info = env.step(action)
            reward = reward if not terminal else -reward
            state_next = np.reshape(state_next, [1, observation_space])
            dqn_solver.remember(state, action, reward, state_next, terminal)
            state = state_next
            if terminal:
                print("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
                score_logger.add_score(step, run)
                break
            dqn_solver.experience_replay()


if __name__ == "__main__":
    cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 9
# Scores: (min: 9, avg: 9, max: 9)
#
# Run: 2, exploration: 0.9229311239742362, score: 27
# Scores: (min: 9, avg: 18, max: 27)
#
# Run: 3, exploration: 0.8690529955452602, score: 13
# Scores: (min: 9, avg: 16.333333333333332, max: 27)
#
# Run: 4, exploration: 0.7822236754458713, score: 22
# Scores: (min: 9, avg: 17.75, max: 27)
#
# Run: 5, exploration: 0.6730128848950395, score: 31
# Scores: (min: 9, avg: 20.4, max: 31)
#
# Run: 6, exploration: 0.6180388156137953, score: 18
# Scores: (min: 9, avg: 20, max: 31)
#
# Run: 7, exploration: 0.5704072587541458, score: 17
# Scores: (min: 9, avg: 19.571428571428573, max: 31)
#
# Run: 8, exploration: 0.5398075216808175, score: 12
# Scores: (min: 9, avg: 18.625, max: 31)
#
# Run: 9, exploration: 0.5057535983897912, score: 14
# Scores: (min: 9, avg: 18.11111111111111, max: 31)
#
# Run: 10, exploration: 0.4810273709480478, score: 11
# Scores: (min: 9, avg: 17.4, max: 31)
#
# Run: 11, exploration: 0.4484282034609769, score: 15
# Scores: (min: 9, avg: 17.181818181818183, max: 31)
#
# Run: 12, exploration: 0.42437208406280985, score: 12
# Scores: (min: 9, avg: 16.75, max: 31)
#
# Run: 13, exploration: 0.4036245882390106, score: 11
# Scores: (min: 9, avg: 16.307692307692307, max: 31)
#
# Run: 14, exploration: 0.3800621177172763, score: 13
# Scores: (min: 9, avg: 16.071428571428573, max: 31)
#
# Run: 15, exploration: 0.3632974174544486, score: 10
# Scores: (min: 9, avg: 15.666666666666666, max: 31)
#
# Run: 16, exploration: 0.3472722151889232, score: 10
# Scores: (min: 9, avg: 15.3125, max: 31)
#
# Run: 17, exploration: 0.32864265128599696, score: 12
# Scores: (min: 9, avg: 15.117647058823529, max: 31)
#
# Run: 18, exploration: 0.31101247816653554, score: 12
# Scores: (min: 9, avg: 14.944444444444445, max: 31)
#
# Run: 19, exploration: 0.2943280830920294, score: 12
# Scores: (min: 9, avg: 14.789473684210526, max: 31)
#
# Run: 20, exploration: 0.28134514724562876, score: 10
# Scores: (min: 9, avg: 14.55, max: 31)
#
# Run: 21, exploration: 0.2662522686041882, score: 12
# Scores: (min: 9, avg: 14.428571428571429, max: 31)
#
# Run: 22, exploration: 0.2507092085103961, score: 13
# Scores: (min: 9, avg: 14.363636363636363, max: 31)
#
# Run: 23, exploration: 0.2408545925762412, score: 9
# Scores: (min: 9, avg: 14.130434782608695, max: 31)
#
# Run: 24, exploration: 0.23023039494318503, score: 10
# Scores: (min: 9, avg: 13.958333333333334, max: 31)
#
# Run: 25, exploration: 0.2211807388415433, score: 9
# Scores: (min: 9, avg: 13.76, max: 31)
#
# Run: 26, exploration: 0.21355457002808648, score: 8
# Scores: (min: 8, avg: 13.538461538461538, max: 31)
#
# Run: 27, exploration: 0.2031139149609751, score: 11
# Scores: (min: 8, avg: 13.444444444444445, max: 31)
#
# Run: 28, exploration: 0.192217783647157, score: 12
# Scores: (min: 8, avg: 13.392857142857142, max: 31)
#
# Run: 29, exploration: 0.18559023879528855, score: 8
# Scores: (min: 8, avg: 13.206896551724139, max: 31)
#
# Run: 30, exploration: 0.17740377510930716, score: 10
# Scores: (min: 8, avg: 13.1, max: 31)
#
# Run: 31, exploration: 0.16957841978827493, score: 10
# Scores: (min: 8, avg: 13, max: 31)
#
# Run: 32, exploration: 0.16048131420416054, score: 12
# Scores: (min: 8, avg: 12.96875, max: 31)
#
# Run: 33, exploration: 0.15035730121053842, score: 14
# Scores: (min: 8, avg: 13, max: 31)
#
# Run: 34, exploration: 0.14229132060898236, score: 12
# Scores: (min: 8, avg: 12.970588235294118, max: 31)
#
# Run: 35, exploration: 0.13398475271138335, score: 13
# Scores: (min: 8, avg: 12.971428571428572, max: 31)
#
# Run: 36, exploration: 0.1255322834371622, score: 14
# Scores: (min: 8, avg: 13, max: 31)
#
# Run: 37, exploration: 0.11939502647758558, score: 11
# Scores: (min: 8, avg: 12.945945945945946, max: 31)
#
# Run: 38, exploration: 0.11299003011401039, score: 12
# Scores: (min: 8, avg: 12.921052631578947, max: 31)
#
# Run: 39, exploration: 0.10800599224428936, score: 10
# Scores: (min: 8, avg: 12.846153846153847, max: 31)
#
# Run: 40, exploration: 0.10272559337455119, score: 11
# Scores: (min: 8, avg: 12.8, max: 31)
#
# Run: 41, exploration: 0.09386293109673778, score: 19
# Scores: (min: 8, avg: 12.951219512195122, max: 31)
#
# Run: 42, exploration: 0.08157186144027828, score: 29
# Scores: (min: 8, avg: 13.333333333333334, max: 31)
#
# Run: 43, exploration: 0.07305469791585968, score: 23
# Scores: (min: 8, avg: 13.55813953488372, max: 31)
#
# Run: 44, exploration: 0.06477420436570952, score: 25
# Scores: (min: 8, avg: 13.818181818181818, max: 31)
#
# Run: 45, exploration: 0.058010934765067, score: 23
# Scores: (min: 8, avg: 14.022222222222222, max: 31)
#
# Run: 46, exploration: 0.05169406930342616, score: 24
# Scores: (min: 8, avg: 14.23913043478261, max: 31)
#
# Run: 47, exploration: 0.04652918187562211, score: 22
# Scores: (min: 8, avg: 14.404255319148936, max: 31)
#
# Run: 48, exploration: 0.04063952250178857, score: 28
# Scores: (min: 8, avg: 14.6875, max: 31)
#
# Run: 49, exploration: 0.03549537564593805, score: 28
# Scores: (min: 8, avg: 14.959183673469388, max: 31)
#
# Run: 50, exploration: 0.029634846598205186, score: 37
# Scores: (min: 8, avg: 15.4, max: 37)
#
# Run: 51, exploration: 0.024008889611965685, score: 43
# Scores: (min: 8, avg: 15.941176470588236, max: 43)
#
# Run: 52, exploration: 0.018592988164936427, score: 52
# Scores: (min: 8, avg: 16.634615384615383, max: 52)
#
# Run: 53, exploration: 0.013490447637165436, score: 65
# Scores: (min: 8, avg: 17.547169811320753, max: 65)
#
# Run: 54, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 18.574074074074073, max: 73)
#
# Run: 55, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 19.181818181818183, max: 73)
#
# Run: 56, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 19.714285714285715, max: 73)
#
# Run: 57, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 20.228070175438596, max: 73)
#
# Run: 58, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 20.413793103448278, max: 73)
#
# Run: 59, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 20.89830508474576, max: 73)
#
# Run: 60, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 21.4, max: 73)
#
# Run: 61, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 21.65573770491803, max: 73)
#
# Run: 62, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 22.35483870967742, max: 73)
#
# Run: 63, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 22.603174603174605, max: 73)
#
# Run: 64, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 23.09375, max: 73)
#
# Run: 65, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 23.476923076923075, max: 73)
#
# Run: 66, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 24.333333333333332, max: 80)
#
# Run: 67, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 25.059701492537314, max: 80)
#
# Run: 68, exploration: 0.01, score: 79
# Scores: (min: 8, avg: 25.852941176470587, max: 80)
#
# Run: 69, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 26.231884057971016, max: 80)
#
# Run: 70, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 26.728571428571428, max: 80)
#
# Run: 71, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 26.985915492957748, max: 80)
#
# Run: 72, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 28.541666666666668, max: 139)
#
# Run: 73, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 29.21917808219178, max: 139)
#
# Run: 74, exploration: 0.01, score: 203
# Scores: (min: 8, avg: 31.56756756756757, max: 203)
#
# Run: 75, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 32.6, max: 203)
#
# Run: 76, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 38.75, max: 500)
#
# Run: 77, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 41.05194805194805, max: 500)
#
# Run: 78, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 42.84615384615385, max: 500)
#
# Run: 79, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 44.79746835443038, max: 500)
#
# Run: 80, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 46.4875, max: 500)
#
# Run: 81, exploration: 0.01, score: 232
# Scores: (min: 8, avg: 48.77777777777778, max: 500)
#
# Run: 82, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 50.18292682926829, max: 500)
#
# Run: 83, exploration: 0.01, score: 196
# Scores: (min: 8, avg: 51.93975903614458, max: 500)
#
# Run: 84, exploration: 0.01, score: 285
# Scores: (min: 8, avg: 54.714285714285715, max: 500)
#
# Run: 85, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 56.529411764705884, max: 500)
#
# Run: 86, exploration: 0.01, score: 242
# Scores: (min: 8, avg: 58.68604651162791, max: 500)
#
# Run: 87, exploration: 0.01, score: 222
# Scores: (min: 8, avg: 60.5632183908046, max: 500)
#
# Run: 88, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 61.90909090909091, max: 500)
#
# Run: 89, exploration: 0.01, score: 205
# Scores: (min: 8, avg: 63.51685393258427, max: 500)
#
# Run: 90, exploration: 0.01, score: 204
# Scores: (min: 8, avg: 65.07777777777778, max: 500)
#
# Run: 91, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 66.47252747252747, max: 500)
#
# Run: 92, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 67.67391304347827, max: 500)
#
# Run: 93, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 68.6236559139785, max: 500)
#
# Run: 94, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 69.7127659574468, max: 500)
#
# Run: 95, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 70.67368421052632, max: 500)
#
# Run: 96, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 71.77083333333333, max: 500)
#
# Run: 97, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 72.73195876288659, max: 500)
#
# Run: 98, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 73.91836734693878, max: 500)
#
# Run: 99, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 75.05050505050505, max: 500)
#
# Run: 100, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 75.95, max: 500)
#
# Run: 101, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 77.48, max: 500)
#
# Run: 102, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 78.97, max: 500)
#
# Run: 103, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 80.41, max: 500)
#
# Run: 104, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 82, max: 500)
#
# Run: 105, exploration: 0.01, score: 187
# Scores: (min: 8, avg: 83.56, max: 500)
#
# Run: 106, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 84.94, max: 500)
#
# Run: 107, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 86.69, max: 500)
#
# Run: 108, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 88.21, max: 500)
#
# Run: 109, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 89.81, max: 500)
#
# Run: 110, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 91.38, max: 500)
#
# Run: 111, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 93.09, max: 500)
#
# Run: 112, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 94.61, max: 500)
#
# Run: 113, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 96.01, max: 500)
#
# Run: 114, exploration: 0.01, score: 237
# Scores: (min: 8, avg: 98.25, max: 500)
#
# Run: 115, exploration: 0.01, score: 187
# Scores: (min: 8, avg: 100.02, max: 500)
#
# Run: 116, exploration: 0.01, score: 187
# Scores: (min: 8, avg: 101.79, max: 500)
#
# Run: 117, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 103.41, max: 500)
#
# Run: 118, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 105.09, max: 500)
#
# Run: 119, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 106.58, max: 500)
#
# Run: 120, exploration: 0.01, score: 191
# Scores: (min: 8, avg: 108.39, max: 500)
#
# Run: 121, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 109.83, max: 500)
#
# Run: 122, exploration: 0.01, score: 207
# Scores: (min: 8, avg: 111.77, max: 500)
#
# Run: 123, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 113.1, max: 500)
#
# Run: 124, exploration: 0.01, score: 239
# Scores: (min: 8, avg: 115.39, max: 500)
#
# Run: 125, exploration: 0.01, score: 228
# Scores: (min: 8, avg: 117.58, max: 500)
#
# Run: 126, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 119.18, max: 500)
#
# Run: 127, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 120.93, max: 500)
#
# Run: 128, exploration: 0.01, score: 191
# Scores: (min: 8, avg: 122.72, max: 500)
#
# Run: 129, exploration: 0.01, score: 173
# Scores: (min: 10, avg: 124.37, max: 500)
#
# Run: 130, exploration: 0.01, score: 161
# Scores: (min: 10, avg: 125.88, max: 500)
#
# Run: 131, exploration: 0.01, score: 154
# Scores: (min: 10, avg: 127.32, max: 500)
#
# Run: 132, exploration: 0.01, score: 123
# Scores: (min: 10, avg: 128.43, max: 500)
#
# Run: 133, exploration: 0.01, score: 296
# Scores: (min: 10, avg: 131.25, max: 500)
#
# Run: 134, exploration: 0.01, score: 199
# Scores: (min: 10, avg: 133.12, max: 500)
#
# Run: 135, exploration: 0.01, score: 247
# Scores: (min: 10, avg: 135.46, max: 500)
#
# Run: 136, exploration: 0.01, score: 176
# Scores: (min: 10, avg: 137.08, max: 500)
#
# Run: 137, exploration: 0.01, score: 345
# Scores: (min: 10, avg: 140.42, max: 500)
#
# Run: 138, exploration: 0.01, score: 210
# Scores: (min: 10, avg: 142.4, max: 500)
#
# Run: 139, exploration: 0.01, score: 221
# Scores: (min: 11, avg: 144.51, max: 500)
#
# Run: 140, exploration: 0.01, score: 265
# Scores: (min: 19, avg: 147.05, max: 500)
#
# Run: 141, exploration: 0.01, score: 384
# Scores: (min: 22, avg: 150.7, max: 500)
#
# Run: 142, exploration: 0.01, score: 173
# Scores: (min: 22, avg: 152.14, max: 500)
#
# Run: 143, exploration: 0.01, score: 500
# Scores: (min: 22, avg: 156.91, max: 500)
#
# Run: 144, exploration: 0.01, score: 187
# Scores: (min: 22, avg: 158.53, max: 500)
#
# Run: 145, exploration: 0.01, score: 461
# Scores: (min: 22, avg: 162.91, max: 500)
#
# Run: 146, exploration: 0.01, score: 29
# Scores: (min: 22, avg: 162.96, max: 500)
#
# Run: 147, exploration: 0.01, score: 500
# Scores: (min: 28, avg: 167.74, max: 500)
#
# Run: 148, exploration: 0.01, score: 311
# Scores: (min: 28, avg: 170.57, max: 500)
#
# Run: 149, exploration: 0.01, score: 191
# Scores: (min: 29, avg: 172.2, max: 500)
#
# Run: 150, exploration: 0.01, score: 352
# Scores: (min: 29, avg: 175.35, max: 500)
#
# Run: 151, exploration: 0.01, score: 347
# Scores: (min: 29, avg: 178.39, max: 500)
#
# Run: 152, exploration: 0.01, score: 180
# Scores: (min: 29, avg: 179.67, max: 500)
#
# Run: 153, exploration: 0.01, score: 101
# Scores: (min: 29, avg: 180.03, max: 500)
#
# Run: 154, exploration: 0.01, score: 34
# Scores: (min: 29, avg: 179.64, max: 500)
#
# Run: 155, exploration: 0.01, score: 82
# Scores: (min: 29, avg: 179.94, max: 500)
#
# Run: 156, exploration: 0.01, score: 19
# Scores: (min: 19, avg: 179.64, max: 500)
#
# Run: 157, exploration: 0.01, score: 15
# Scores: (min: 15, avg: 179.3, max: 500)
#
# Run: 158, exploration: 0.01, score: 62
# Scores: (min: 15, avg: 179.61, max: 500)
#
# Run: 159, exploration: 0.01, score: 203
# Scores: (min: 15, avg: 181.15, max: 500)
#
# Run: 160, exploration: 0.01, score: 86
# Scores: (min: 15, avg: 181.5, max: 500)
#
# Run: 161, exploration: 0.01, score: 68
# Scores: (min: 15, avg: 181.81, max: 500)
#
# Run: 162, exploration: 0.01, score: 230
# Scores: (min: 15, avg: 183.46, max: 500)
#
# Run: 163, exploration: 0.01, score: 161
# Scores: (min: 15, avg: 184.69, max: 500)
#
# Run: 164, exploration: 0.01, score: 220
# Scores: (min: 15, avg: 186.35, max: 500)
#
# Run: 165, exploration: 0.01, score: 104
# Scores: (min: 15, avg: 186.91, max: 500)
#
# Run: 166, exploration: 0.01, score: 95
# Scores: (min: 15, avg: 187.06, max: 500)
#
# Run: 167, exploration: 0.01, score: 206
# Scores: (min: 15, avg: 188.39, max: 500)
#
# Run: 168, exploration: 0.01, score: 184
# Scores: (min: 15, avg: 189.44, max: 500)
#
# Run: 169, exploration: 0.01, score: 143
# Scores: (min: 15, avg: 190.35, max: 500)
#
# Run: 170, exploration: 0.01, score: 207
# Scores: (min: 15, avg: 191.81, max: 500)
#
# Run: 171, exploration: 0.01, score: 164
# Scores: (min: 15, avg: 193, max: 500)
#
# Run: 172, exploration: 0.01, score: 117
# Scores: (min: 15, avg: 192.78, max: 500)
#
# Run: 173, exploration: 0.01, score: 263
# Scores: (min: 15, avg: 194.63, max: 500)
#
# Run: 174, exploration: 0.01, score: 221
# Scores: (min: 15, avg: 194.81, max: 500)
#
# Run: 175, exploration: 0.01, score: 158
# Scores: (min: 15, avg: 195.3, max: 500)
#
# Solved in 75 runs, 175 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-edede39ea1ff> in <module>()
#      91
#      92 if __name__ == "__main__":
# ---> 93     cartpole()
#
# <ipython-input-14-edede39ea1ff> in cartpole()
#      85             if terminal:
#      86                 print("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 87                 score_logger.add_score(step, run)
#      88                 break
#      89             dqn_solver.experience_replay()
#
# /content/scores/score_logger.py in add_score(self, score, run)
#      52                            show_trend=False,
#      53                            show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# The code only ran the program on one CPU core which made it horrendously slow, and when I tried to render the gym environment to visualize how it actually performed it ran the image/video AND the training on my CPU and used 24GB of ram on my system!

# %% [markdown]
# Part (a)
# I added a comment above the proper line above^^^^
#
# Part (b)
# According to the linked article and some of my own experiments I found the sufficient number of steps to run the program to be around 131 and that corresponds to a average score of 195 (which is defined as the solving criteria). The author came to these conclusion after running 30 trials until each one solved (got an average score of 195 or above) and then averaged the number of steps over the 30 trials. I ran it myself 6 times until solving and got results of [120, 146, 137, 141, 121, 175]steps. So a good number to choose would be around 131 steps or to be extra confident that it would solve almost every trial I would choose 150 steps.
#
# Part (c)
# For this part I changed the 'act()' function to the following:

# %%
def act2(self, state):
    return random.randrange(self.action_space)

# %%
class DQNSolver:

    def __init__(self, observation_space, action_space):
        self.exploration_rate = EXPLORATION_MAX

        self.action_space = action_space
        self.memory = deque(maxlen=MEMORY_SIZE)

        self.model = Sequential()
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))
        self.model.add(Dense(24, activation="relu"))
        self.model.add(Dense(self.action_space, activation="linear"))
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
    
    #Changed the below function
    def act2(self, state):
      return random.randrange(self.action_space)

    def experience_replay(self):
        if len(self.memory) < BATCH_SIZE:
            return
        batch = random.sample(self.memory, BATCH_SIZE)
        for state, action, reward, state_next, terminal in batch:
            q_update = reward
            if not terminal:
                #The line underneath this comment is where the temperal difference error is calculated
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
            q_values = self.model.predict(state)
            q_values[0][action] = q_update
            self.model.fit(state, q_values, verbose=0)
        self.exploration_rate *= EXPLORATION_DECAY
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)

def cartpole():
    env = gym.make(ENV_NAME)
    score_logger = ScoreLogger(ENV_NAME)
    observation_space = env.observation_space.shape[0]
    action_space = env.action_space.n
    dqn_solver = DQNSolver(observation_space, action_space)
    run = 0
    while True:
        run += 1
        state = env.reset()
        state = np.reshape(state, [1, observation_space])
        step = 0
        while True:
            step += 1
            #env.render()
            action = dqn_solver.act2(state) #Change on this line
            state_next, reward, terminal, info = env.step(action)
            reward = reward if not terminal else -reward
            state_next = np.reshape(state_next, [1, observation_space])
            dqn_solver.remember(state, action, reward, state_next, terminal)
            state = state_next
            if terminal:
                print("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
                score_logger.add_score(step, run)
                break
            dqn_solver.experience_replay()

cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 16
# Scores: (min: 16, avg: 16, max: 16)
#
# Run: 2, exploration: 0.9000874278732445, score: 25
# Scores: (min: 16, avg: 20.5, max: 25)
#
# Run: 3, exploration: 0.7439808620067382, score: 39
# Scores: (min: 16, avg: 26.666666666666668, max: 39)
#
# Run: 4, exploration: 0.7076077347272662, score: 11
# Scores: (min: 11, avg: 22.75, max: 39)
#
# Run: 5, exploration: 0.6242658676435396, score: 26
# Scores: (min: 11, avg: 23.4, max: 39)
#
# Run: 6, exploration: 0.5937455908197752, score: 11
# Scores: (min: 11, avg: 21.333333333333332, max: 39)
#
# Run: 7, exploration: 0.567555222460375, score: 10
# Scores: (min: 10, avg: 19.714285714285715, max: 39)
#
# Run: 8, exploration: 0.4907693883854626, score: 30
# Scores: (min: 10, avg: 21, max: 39)
#
# Run: 9, exploration: 0.4529463432347434, score: 17
# Scores: (min: 10, avg: 20.555555555555557, max: 39)
#
# Run: 10, exploration: 0.4016064652978155, score: 25
# Scores: (min: 10, avg: 21, max: 39)
#
# Run: 11, exploration: 0.37251769488706843, score: 16
# Scores: (min: 10, avg: 20.545454545454547, max: 39)
#
# Run: 12, exploration: 0.3455358541129786, score: 16
# Scores: (min: 10, avg: 20.166666666666668, max: 39)
#
# Run: 13, exploration: 0.326999438029567, score: 12
# Scores: (min: 10, avg: 19.53846153846154, max: 39)
#
# Run: 14, exploration: 0.3079101286968243, score: 13
# Scores: (min: 10, avg: 19.071428571428573, max: 39)
#
# Run: 15, exploration: 0.2799384215094006, score: 20
# Scores: (min: 10, avg: 19.133333333333333, max: 39)
#
# Run: 16, exploration: 0.25450776877280124, score: 20
# Scores: (min: 10, avg: 19.1875, max: 39)
#
# Run: 17, exploration: 0.2167901907234072, score: 33
# Scores: (min: 10, avg: 20, max: 39)
#
# Run: 18, exploration: 0.17829525136613786, score: 40
# Scores: (min: 10, avg: 21.11111111111111, max: 40)
#
# Run: 19, exploration: 0.1557266555690826, score: 28
# Scores: (min: 10, avg: 21.473684210526315, max: 40)
#
# Run: 20, exploration: 0.14444721332374086, score: 16
# Scores: (min: 10, avg: 21.2, max: 40)
#
# Run: 21, exploration: 0.11299003011401039, score: 50
# Scores: (min: 10, avg: 22.571428571428573, max: 50)
#
# Run: 22, exploration: 0.1032418023864836, score: 19
# Scores: (min: 10, avg: 22.40909090909091, max: 50)
#
# Run: 23, exploration: 0.09017346495423652, score: 28
# Scores: (min: 10, avg: 22.652173913043477, max: 50)
#
# Run: 24, exploration: 0.06983222438783, score: 52
# Scores: (min: 10, avg: 23.875, max: 52)
#
# Run: 25, exploration: 0.06254083169574957, score: 23
# Scores: (min: 10, avg: 23.84, max: 52)
#
# Run: 26, exploration: 0.05948321859358224, score: 11
# Scores: (min: 10, avg: 23.346153846153847, max: 52)
#
# Run: 27, exploration: 0.049911691230058335, score: 36
# Scores: (min: 10, avg: 23.814814814814813, max: 52)
#
# Run: 28, exploration: 0.04272851397543923, score: 32
# Scores: (min: 10, avg: 24.107142857142858, max: 52)
#
# Run: 29, exploration: 0.04063952250178857, score: 11
# Scores: (min: 10, avg: 23.655172413793103, max: 52)
#
# Run: 30, exploration: 0.0386526615487428, score: 11
# Scores: (min: 10, avg: 23.233333333333334, max: 52)
#
# Run: 31, exploration: 0.03496560272750046, score: 21
# Scores: (min: 10, avg: 23.161290322580644, max: 52)
#
# Run: 32, exploration: 0.024741930939380097, score: 70
# Scores: (min: 10, avg: 24.625, max: 70)
#
# Run: 33, exploration: 0.02171869316274056, score: 27
# Scores: (min: 10, avg: 24.696969696969695, max: 70)
#
# Run: 34, exploration: 0.01954872266561937, score: 22
# Scores: (min: 10, avg: 24.61764705882353, max: 70)
#
# Run: 35, exploration: 0.018592988164936427, score: 11
# Scores: (min: 10, avg: 24.228571428571428, max: 70)
#
# Run: 36, exploration: 0.016735314893855303, score: 22
# Scores: (min: 10, avg: 24.166666666666668, max: 70)
#
# Run: 37, exploration: 0.014398800381387675, score: 31
# Scores: (min: 10, avg: 24.35135135135135, max: 70)
#
# Run: 38, exploration: 0.012388500230681249, score: 31
# Scores: (min: 10, avg: 24.526315789473685, max: 70)
#
# Run: 39, exploration: 0.011433732442257729, score: 17
# Scores: (min: 10, avg: 24.333333333333332, max: 70)
#
# Run: 40, exploration: 0.010343074195922241, score: 21
# Scores: (min: 10, avg: 24.25, max: 70)
#
# Run: 41, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 24.170731707317074, max: 70)
#
# Run: 42, exploration: 0.01, score: 19
# Scores: (min: 10, avg: 24.047619047619047, max: 70)
#
# Run: 43, exploration: 0.01, score: 30
# Scores: (min: 10, avg: 24.186046511627907, max: 70)
#
# Run: 44, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 23.931818181818183, max: 70)
#
# Run: 45, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 23.866666666666667, max: 70)
#
# Run: 46, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 23.565217391304348, max: 70)
#
# Run: 47, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 23.5531914893617, max: 70)
#
# Run: 48, exploration: 0.01, score: 25
# Scores: (min: 10, avg: 23.583333333333332, max: 70)
#
# Run: 49, exploration: 0.01, score: 34
# Scores: (min: 10, avg: 23.79591836734694, max: 70)
#
# Run: 50, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 23.54, max: 70)
#
# Run: 51, exploration: 0.01, score: 18
# Scores: (min: 10, avg: 23.431372549019606, max: 70)
#
# Run: 52, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 23.384615384615383, max: 70)
#
# Run: 53, exploration: 0.01, score: 18
# Scores: (min: 10, avg: 23.28301886792453, max: 70)
#
# Run: 54, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 23.074074074074073, max: 70)
#
# Run: 55, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 22.818181818181817, max: 70)
#
# Run: 56, exploration: 0.01, score: 42
# Scores: (min: 9, avg: 23.160714285714285, max: 70)
#
# Run: 57, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 22.94736842105263, max: 70)
#
# Run: 58, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 22.862068965517242, max: 70)
#
# Run: 59, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 22.88135593220339, max: 70)
#
# Run: 60, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 22.783333333333335, max: 70)
#
# Run: 61, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 22.721311475409838, max: 70)
#
# Run: 62, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 22.758064516129032, max: 70)
#
# Run: 63, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 22.650793650793652, max: 70)
#
# Run: 64, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 22.671875, max: 70)
#
# Run: 65, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 22.50769230769231, max: 70)
#
# Run: 66, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 22.333333333333332, max: 70)
#
# Run: 67, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 22.238805970149254, max: 70)
#
# Run: 68, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 22.397058823529413, max: 70)
#
# Run: 69, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 22.231884057971016, max: 70)
#
# Run: 70, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 22.114285714285714, max: 70)
#
# Run: 71, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 22.225352112676056, max: 70)
#
# Run: 72, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 22.26388888888889, max: 70)
#
# Run: 73, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 22.095890410958905, max: 70)
#
# Run: 74, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 22.013513513513512, max: 70)
#
# Run: 75, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 22.026666666666667, max: 70)
#
# Run: 76, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 21.960526315789473, max: 70)
#
# Run: 77, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 22.142857142857142, max: 70)
#
# Run: 78, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 22, max: 70)
#
# Run: 79, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 22.126582278481013, max: 70)
#
# Run: 80, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 22.05, max: 70)
#
# Run: 81, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 22.012345679012345, max: 70)
#
# Run: 82, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 22.073170731707318, max: 70)
#
# Run: 83, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 21.951807228915662, max: 70)
#
# Run: 84, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 21.821428571428573, max: 70)
#
# Run: 85, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 21.705882352941178, max: 70)
#
# Run: 86, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 21.790697674418606, max: 70)
#
# Run: 87, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 21.689655172413794, max: 70)
#
# Run: 88, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 21.670454545454547, max: 70)
#
# Run: 89, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 21.629213483146067, max: 70)
#
# Run: 90, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 21.61111111111111, max: 70)
#
# Run: 91, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 21.47252747252747, max: 70)
#
# Run: 92, exploration: 0.01, score: 45
# Scores: (min: 9, avg: 21.72826086956522, max: 70)
#
# Run: 93, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 21.666666666666668, max: 70)
#
# Run: 94, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 21.54255319148936, max: 70)
#
# Run: 95, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 21.49473684210526, max: 70)
#
# Run: 96, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 21.427083333333332, max: 70)
#
# Run: 97, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 21.38144329896907, max: 70)
#
# Run: 98, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 21.387755102040817, max: 70)
#
# Run: 99, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 21.434343434343436, max: 70)
#
# Run: 100, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 21.36, max: 70)
#
# Run: 101, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 21.36, max: 70)
#
# Run: 102, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 21.37, max: 70)
#
# Run: 103, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 21.2, max: 70)
#
# Run: 104, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 21.52, max: 70)
#
# Run: 105, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 21.46, max: 70)
#
# Run: 106, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 21.55, max: 70)
#
# Run: 107, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 21.78, max: 70)
#
# Run: 108, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 21.64, max: 70)
#
# Run: 109, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 21.61, max: 70)
#
# Run: 110, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 21.5, max: 70)
#
# Run: 111, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 21.47, max: 70)
#
# Run: 112, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 21.6, max: 70)
#
# Run: 113, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 21.8, max: 70)
#
# Run: 114, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 21.88, max: 70)
#
# Run: 115, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 21.94, max: 70)
#
# Run: 116, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 21.98, max: 70)
#
# Run: 117, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 21.83, max: 70)
#
# Run: 118, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 21.59, max: 70)
#
# Run: 119, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 21.44, max: 70)
#
# Run: 120, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 21.41, max: 70)
#
# Run: 121, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 21.03, max: 70)
#
# Run: 122, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 21.07, max: 70)
#
# Run: 123, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 20.96, max: 70)
#
# Run: 124, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 20.57, max: 70)
#
# Run: 125, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 20.5, max: 70)
#
# Run: 126, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 20.52, max: 70)
#
# Run: 127, exploration: 0.01, score: 49
# Scores: (min: 9, avg: 20.65, max: 70)
#
# Run: 128, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 20.6, max: 70)
#
# Run: 129, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 20.79, max: 70)
#
# Run: 130, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 20.81, max: 70)
#
# Run: 131, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 20.71, max: 70)
#
# Run: 132, exploration: 0.01, score: 97
# Scores: (min: 9, avg: 20.98, max: 97)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-20fc4418525f> in <module>()
#      60             dqn_solver.experience_replay()
#      61
# ---> 62 cartpole()
#
# <ipython-input-11-20fc4418525f> in cartpole()
#      58                 score_logger.add_score(step, run)
#      59                 break
# ---> 60             dqn_solver.experience_replay()
#      61
#      62 cartpole()
#
# <ipython-input-11-20fc4418525f> in experience_replay(self)
#      30             q_values = self.model.predict(state)
#      31             q_values[0][action] = q_update
# ---> 32             self.model.fit(state, q_values, verbose=0)
#      33         self.exploration_rate *= EXPLORATION_DECAY
#      34         self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     725         max_queue_size=max_queue_size,
#     726         workers=workers,
# --> 727         use_multiprocessing=use_multiprocessing)
#     728
#     729   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     673         validation_steps=validation_steps,
#     674         validation_freq=validation_freq,
# --> 675         steps_name='steps_per_epoch')
#     676
#     677   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     392
#     393         # Get outputs.
# --> 394         batch_outs = f(ins_batch)
#     395         if not isinstance(batch_outs, list):
#     396           batch_outs = [batch_outs]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# And then after 131 steps I was left with an average score of: 20.71, well under 195 it should be near.

# %% [markdown]
# Part (d)
# To keep exploration at .2 I changed the following global variables: (I also used the original act() 'function')

# %%
EXPLORATION_MAX = 0.2  
EXPLORATION_MIN = 0.2   
EXPLORATION_DECAY = 1

class DQNSolver:

    def __init__(self, observation_space, action_space):
        self.exploration_rate = EXPLORATION_MAX

        self.action_space = action_space
        self.memory = deque(maxlen=MEMORY_SIZE)

        self.model = Sequential()
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))
        self.model.add(Dense(24, activation="relu"))
        self.model.add(Dense(self.action_space, activation="linear"))
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
    
    #Changed the below function
    def act(self, state):
        if np.random.rand() < self.exploration_rate:
            return random.randrange(self.action_space)
        q_values = self.model.predict(state)
        return np.argmax(q_values[0])

    def experience_replay(self):
        if len(self.memory) < BATCH_SIZE:
            return
        batch = random.sample(self.memory, BATCH_SIZE)
        for state, action, reward, state_next, terminal in batch:
            q_update = reward
            if not terminal:
                #The line underneath this comment is where the temperal difference error is calculated
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
            q_values = self.model.predict(state)
            q_values[0][action] = q_update
            self.model.fit(state, q_values, verbose=0)
        self.exploration_rate *= EXPLORATION_DECAY
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)
        
def cartpole():
    env = gym.make(ENV_NAME)
    score_logger = ScoreLogger(ENV_NAME)
    observation_space = env.observation_space.shape[0]
    action_space = env.action_space.n
    dqn_solver = DQNSolver(observation_space, action_space)
    run = 0
    while True:
        run += 1
        state = env.reset()
        state = np.reshape(state, [1, observation_space])
        step = 0
        while True:
            step += 1
            #env.render()
            action = dqn_solver.act(state) #Change on this line
            state_next, reward, terminal, info = env.step(action)
            reward = reward if not terminal else -reward
            state_next = np.reshape(state_next, [1, observation_space])
            dqn_solver.remember(state, action, reward, state_next, terminal)
            state = state_next
            if terminal:
                print("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
                score_logger.add_score(step, run)
                break
            dqn_solver.experience_replay()

cartpole()
# Out:
# Run: 1, exploration: 0.2, score: 14
# Scores: (min: 14, avg: 14, max: 14)
#
# Run: 2, exploration: 0.2, score: 9
# Scores: (min: 9, avg: 11.5, max: 14)
#
# Run: 3, exploration: 0.2, score: 9
# Scores: (min: 9, avg: 10.666666666666666, max: 14)
#
# Run: 4, exploration: 0.2, score: 9
# Scores: (min: 9, avg: 10.25, max: 14)
#
# Run: 5, exploration: 0.2, score: 12
# Scores: (min: 9, avg: 10.6, max: 14)
#
# Run: 6, exploration: 0.2, score: 8
# Scores: (min: 8, avg: 10.166666666666666, max: 14)
#
# Run: 7, exploration: 0.2, score: 11
# Scores: (min: 8, avg: 10.285714285714286, max: 14)
#
# Run: 8, exploration: 0.2, score: 16
# Scores: (min: 8, avg: 11, max: 16)
#
# Run: 9, exploration: 0.2, score: 13
# Scores: (min: 8, avg: 11.222222222222221, max: 16)
#
# Run: 10, exploration: 0.2, score: 12
# Scores: (min: 8, avg: 11.3, max: 16)
#
# Run: 11, exploration: 0.2, score: 10
# Scores: (min: 8, avg: 11.181818181818182, max: 16)
#
# Run: 12, exploration: 0.2, score: 13
# Scores: (min: 8, avg: 11.333333333333334, max: 16)
#
# Run: 13, exploration: 0.2, score: 20
# Scores: (min: 8, avg: 12, max: 20)
#
# Run: 14, exploration: 0.2, score: 22
# Scores: (min: 8, avg: 12.714285714285714, max: 22)
#
# Run: 15, exploration: 0.2, score: 48
# Scores: (min: 8, avg: 15.066666666666666, max: 48)
#
# Run: 16, exploration: 0.2, score: 31
# Scores: (min: 8, avg: 16.0625, max: 48)
#
# Run: 17, exploration: 0.2, score: 112
# Scores: (min: 8, avg: 21.705882352941178, max: 112)
#
# Run: 18, exploration: 0.2, score: 20
# Scores: (min: 8, avg: 21.61111111111111, max: 112)
#
# Run: 19, exploration: 0.2, score: 24
# Scores: (min: 8, avg: 21.736842105263158, max: 112)
#
# Run: 20, exploration: 0.2, score: 56
# Scores: (min: 8, avg: 23.45, max: 112)
#
# Run: 21, exploration: 0.2, score: 54
# Scores: (min: 8, avg: 24.904761904761905, max: 112)
#
# Run: 22, exploration: 0.2, score: 44
# Scores: (min: 8, avg: 25.772727272727273, max: 112)
#
# Run: 23, exploration: 0.2, score: 81
# Scores: (min: 8, avg: 28.17391304347826, max: 112)
#
# Run: 24, exploration: 0.2, score: 56
# Scores: (min: 8, avg: 29.333333333333332, max: 112)
#
# Run: 25, exploration: 0.2, score: 39
# Scores: (min: 8, avg: 29.72, max: 112)
#
# Run: 26, exploration: 0.2, score: 149
# Scores: (min: 8, avg: 34.30769230769231, max: 149)
#
# Run: 27, exploration: 0.2, score: 156
# Scores: (min: 8, avg: 38.81481481481482, max: 156)
#
# Run: 28, exploration: 0.2, score: 127
# Scores: (min: 8, avg: 41.964285714285715, max: 156)
#
# Run: 29, exploration: 0.2, score: 189
# Scores: (min: 8, avg: 47.03448275862069, max: 189)
#
# Run: 30, exploration: 0.2, score: 204
# Scores: (min: 8, avg: 52.266666666666666, max: 204)
#
# Run: 31, exploration: 0.2, score: 219
# Scores: (min: 8, avg: 57.645161290322584, max: 219)
#
# Run: 32, exploration: 0.2, score: 188
# Scores: (min: 8, avg: 61.71875, max: 219)
#
# Run: 33, exploration: 0.2, score: 167
# Scores: (min: 8, avg: 64.9090909090909, max: 219)
#
# Run: 34, exploration: 0.2, score: 162
# Scores: (min: 8, avg: 67.76470588235294, max: 219)
#
# Run: 35, exploration: 0.2, score: 219
# Scores: (min: 8, avg: 72.08571428571429, max: 219)
#
# Run: 36, exploration: 0.2, score: 203
# Scores: (min: 8, avg: 75.72222222222223, max: 219)
#
# Run: 37, exploration: 0.2, score: 209
# Scores: (min: 8, avg: 79.32432432432432, max: 219)
#
# Run: 38, exploration: 0.2, score: 211
# Scores: (min: 8, avg: 82.78947368421052, max: 219)
#
# Run: 39, exploration: 0.2, score: 311
# Scores: (min: 8, avg: 88.64102564102564, max: 311)
#
# Run: 40, exploration: 0.2, score: 196
# Scores: (min: 8, avg: 91.325, max: 311)
#
# Run: 41, exploration: 0.2, score: 384
# Scores: (min: 8, avg: 98.46341463414635, max: 384)
#
# Run: 42, exploration: 0.2, score: 201
# Scores: (min: 8, avg: 100.9047619047619, max: 384)
#
# Run: 43, exploration: 0.2, score: 203
# Scores: (min: 8, avg: 103.27906976744185, max: 384)
#
# Run: 44, exploration: 0.2, score: 203
# Scores: (min: 8, avg: 105.54545454545455, max: 384)
#
# Run: 45, exploration: 0.2, score: 147
# Scores: (min: 8, avg: 106.46666666666667, max: 384)
#
# Run: 46, exploration: 0.2, score: 118
# Scores: (min: 8, avg: 106.71739130434783, max: 384)
#
# Run: 47, exploration: 0.2, score: 188
# Scores: (min: 8, avg: 108.44680851063829, max: 384)
#
# Run: 48, exploration: 0.2, score: 99
# Scores: (min: 8, avg: 108.25, max: 384)
#
# Run: 49, exploration: 0.2, score: 212
# Scores: (min: 8, avg: 110.36734693877551, max: 384)
#
# Run: 50, exploration: 0.2, score: 23
# Scores: (min: 8, avg: 108.62, max: 384)
#
# Run: 51, exploration: 0.2, score: 15
# Scores: (min: 8, avg: 106.7843137254902, max: 384)
#
# Run: 52, exploration: 0.2, score: 73
# Scores: (min: 8, avg: 106.13461538461539, max: 384)
#
# Run: 53, exploration: 0.2, score: 205
# Scores: (min: 8, avg: 108, max: 384)
#
# Run: 54, exploration: 0.2, score: 158
# Scores: (min: 8, avg: 108.92592592592592, max: 384)
#
# Run: 55, exploration: 0.2, score: 19
# Scores: (min: 8, avg: 107.2909090909091, max: 384)
#
# Run: 56, exploration: 0.2, score: 170
# Scores: (min: 8, avg: 108.41071428571429, max: 384)
#
# Run: 57, exploration: 0.2, score: 186
# Scores: (min: 8, avg: 109.7719298245614, max: 384)
#
# Run: 58, exploration: 0.2, score: 167
# Scores: (min: 8, avg: 110.75862068965517, max: 384)
#
# Run: 59, exploration: 0.2, score: 312
# Scores: (min: 8, avg: 114.16949152542372, max: 384)
#
# Run: 60, exploration: 0.2, score: 259
# Scores: (min: 8, avg: 116.58333333333333, max: 384)
#
# Run: 61, exploration: 0.2, score: 386
# Scores: (min: 8, avg: 121, max: 386)
#
# Run: 62, exploration: 0.2, score: 39
# Scores: (min: 8, avg: 119.6774193548387, max: 386)
#
# Run: 63, exploration: 0.2, score: 46
# Scores: (min: 8, avg: 118.5079365079365, max: 386)
#
# Run: 64, exploration: 0.2, score: 231
# Scores: (min: 8, avg: 120.265625, max: 386)
#
# Run: 65, exploration: 0.2, score: 231
# Scores: (min: 8, avg: 121.96923076923076, max: 386)
#
# Run: 66, exploration: 0.2, score: 261
# Scores: (min: 8, avg: 124.07575757575758, max: 386)
#
# Run: 67, exploration: 0.2, score: 251
# Scores: (min: 8, avg: 125.97014925373135, max: 386)
#
# Run: 68, exploration: 0.2, score: 84
# Scores: (min: 8, avg: 125.3529411764706, max: 386)
#
# Run: 69, exploration: 0.2, score: 215
# Scores: (min: 8, avg: 126.65217391304348, max: 386)
#
# Run: 70, exploration: 0.2, score: 282
# Scores: (min: 8, avg: 128.87142857142857, max: 386)
#
# Run: 71, exploration: 0.2, score: 281
# Scores: (min: 8, avg: 131.01408450704224, max: 386)
#
# Run: 72, exploration: 0.2, score: 305
# Scores: (min: 8, avg: 133.43055555555554, max: 386)
#
# Run: 73, exploration: 0.2, score: 264
# Scores: (min: 8, avg: 135.21917808219177, max: 386)
#
# Run: 74, exploration: 0.2, score: 88
# Scores: (min: 8, avg: 134.5810810810811, max: 386)
#
# Run: 75, exploration: 0.2, score: 181
# Scores: (min: 8, avg: 135.2, max: 386)
#
# Run: 76, exploration: 0.2, score: 329
# Scores: (min: 8, avg: 137.75, max: 386)
#
# Run: 77, exploration: 0.2, score: 196
# Scores: (min: 8, avg: 138.5064935064935, max: 386)
#
# Run: 78, exploration: 0.2, score: 120
# Scores: (min: 8, avg: 138.26923076923077, max: 386)
#
# Run: 79, exploration: 0.2, score: 255
# Scores: (min: 8, avg: 139.74683544303798, max: 386)
#
# Run: 80, exploration: 0.2, score: 113
# Scores: (min: 8, avg: 139.4125, max: 386)
#
# Run: 81, exploration: 0.2, score: 235
# Scores: (min: 8, avg: 140.59259259259258, max: 386)
#
# Run: 82, exploration: 0.2, score: 277
# Scores: (min: 8, avg: 142.2560975609756, max: 386)
#
# Run: 83, exploration: 0.2, score: 176
# Scores: (min: 8, avg: 142.66265060240963, max: 386)
#
# Run: 84, exploration: 0.2, score: 444
# Scores: (min: 8, avg: 146.25, max: 444)
#
# Run: 85, exploration: 0.2, score: 291
# Scores: (min: 8, avg: 147.95294117647057, max: 444)
#
# Run: 86, exploration: 0.2, score: 500
# Scores: (min: 8, avg: 152.04651162790697, max: 500)
#
# Run: 87, exploration: 0.2, score: 116
# Scores: (min: 8, avg: 151.632183908046, max: 500)
#
# Run: 88, exploration: 0.2, score: 403
# Scores: (min: 8, avg: 154.48863636363637, max: 500)
#
# Run: 89, exploration: 0.2, score: 206
# Scores: (min: 8, avg: 155.06741573033707, max: 500)
#
# Run: 90, exploration: 0.2, score: 174
# Scores: (min: 8, avg: 155.27777777777777, max: 500)
#
# Run: 91, exploration: 0.2, score: 219
# Scores: (min: 8, avg: 155.97802197802199, max: 500)
#
# Run: 92, exploration: 0.2, score: 383
# Scores: (min: 8, avg: 158.44565217391303, max: 500)
#
# Run: 93, exploration: 0.2, score: 100
# Scores: (min: 8, avg: 157.81720430107526, max: 500)
#
# Run: 94, exploration: 0.2, score: 44
# Scores: (min: 8, avg: 156.60638297872342, max: 500)
#
# Run: 95, exploration: 0.2, score: 241
# Scores: (min: 8, avg: 157.49473684210525, max: 500)
#
# Run: 96, exploration: 0.2, score: 259
# Scores: (min: 8, avg: 158.55208333333334, max: 500)
#
# Run: 97, exploration: 0.2, score: 75
# Scores: (min: 8, avg: 157.69072164948454, max: 500)
#
# Run: 98, exploration: 0.2, score: 24
# Scores: (min: 8, avg: 156.3265306122449, max: 500)
#
# Run: 99, exploration: 0.2, score: 389
# Scores: (min: 8, avg: 158.67676767676767, max: 500)
#
# Run: 100, exploration: 0.2, score: 154
# Scores: (min: 8, avg: 158.63, max: 500)
#
# Run: 101, exploration: 0.2, score: 108
# Scores: (min: 8, avg: 159.57, max: 500)
#
# Run: 102, exploration: 0.2, score: 184
# Scores: (min: 8, avg: 161.32, max: 500)
#
# Run: 103, exploration: 0.2, score: 76
# Scores: (min: 8, avg: 161.99, max: 500)
#
# Run: 104, exploration: 0.2, score: 132
# Scores: (min: 8, avg: 163.22, max: 500)
#
# Run: 105, exploration: 0.2, score: 128
# Scores: (min: 8, avg: 164.38, max: 500)
#
# Run: 106, exploration: 0.2, score: 408
# Scores: (min: 10, avg: 168.38, max: 500)
#
# Run: 107, exploration: 0.2, score: 282
# Scores: (min: 10, avg: 171.09, max: 500)
#
# Run: 108, exploration: 0.2, score: 445
# Scores: (min: 10, avg: 175.38, max: 500)
#
# Run: 109, exploration: 0.2, score: 132
# Scores: (min: 10, avg: 176.57, max: 500)
#
# Run: 110, exploration: 0.2, score: 168
# Scores: (min: 10, avg: 178.13, max: 500)
#
# Run: 111, exploration: 0.2, score: 49
# Scores: (min: 13, avg: 178.52, max: 500)
#
# Run: 112, exploration: 0.2, score: 129
# Scores: (min: 15, avg: 179.68, max: 500)
#
# Run: 113, exploration: 0.2, score: 142
# Scores: (min: 15, avg: 180.9, max: 500)
#
# Run: 114, exploration: 0.2, score: 125
# Scores: (min: 15, avg: 181.93, max: 500)
#
# Run: 115, exploration: 0.2, score: 144
# Scores: (min: 15, avg: 182.89, max: 500)
#
# Run: 116, exploration: 0.2, score: 37
# Scores: (min: 15, avg: 182.95, max: 500)
#
# Run: 117, exploration: 0.2, score: 207
# Scores: (min: 15, avg: 183.9, max: 500)
#
# Run: 118, exploration: 0.2, score: 48
# Scores: (min: 15, avg: 184.18, max: 500)
#
# Run: 119, exploration: 0.2, score: 121
# Scores: (min: 15, avg: 185.15, max: 500)
#
# Run: 120, exploration: 0.2, score: 356
# Scores: (min: 15, avg: 188.15, max: 500)
#
# Run: 121, exploration: 0.2, score: 364
# Scores: (min: 15, avg: 191.25, max: 500)
#
# Run: 122, exploration: 0.2, score: 120
# Scores: (min: 15, avg: 192.01, max: 500)
#
# Run: 123, exploration: 0.2, score: 105
# Scores: (min: 15, avg: 192.25, max: 500)
#
# Run: 124, exploration: 0.2, score: 114
# Scores: (min: 15, avg: 192.83, max: 500)
#
# Run: 125, exploration: 0.2, score: 213
# Scores: (min: 15, avg: 194.57, max: 500)
#
# Run: 126, exploration: 0.2, score: 95
# Scores: (min: 15, avg: 194.03, max: 500)
#
# Run: 127, exploration: 0.2, score: 500
# Scores: (min: 15, avg: 197.47, max: 500)
#
# Solved in 27 runs, 127 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8e8e548591dd> in <module>()
#      69             dqn_solver.experience_replay()
#      70
# ---> 71 cartpole()
#
# <ipython-input-13-8e8e548591dd> in cartpole()
#      65             if terminal:
#      66                 print("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 67                 score_logger.add_score(step, run)
#      68                 break
#      69             dqn_solver.experience_replay()
#
# /content/scores/score_logger.py in add_score(self, score, run)
#      52                            show_trend=False,
#      53                            show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Then it reached an average score of 197.47 after 127 steps.
# Which is on par with the default results. Could have been a good run, but we'll leave it at that.
